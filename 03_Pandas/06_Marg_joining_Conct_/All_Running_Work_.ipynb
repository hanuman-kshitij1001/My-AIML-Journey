# %%
import pandas as pd
matches = pd.read_csv("All Data Sets/03_Data_Set_matches.csv")
print(matches)

# %%
import pandas as pd
course = pd.read_csv("All Data Sets/01_DataSet_courses.csv")
course
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
import pandas as pd
deliveries = pd.read_csv("All Data Sets/02_Data_Set_deliveries (1).csv")
deliveries

# %%
import pandas as pd
nov = pd.read_csv("All Data Sets/04_Data_Set_reg-month1.csv")
nov

# %%
import pandas as pd
dec = pd.read_csv("All Data Sets/05_Data_Set_reg-month2.csv")
print(dec)
a = dec.shape
print(a)

# %%
import pandas as pd
import numpy as np
nov = pd.read_csv("All Data Sets/04_Data_Set_reg-month1.csv")
dec = pd.read_csv("All Data Sets/05_Data_Set_reg-month2.csv")

df = pd.concat([nov, dec], ignore_index=True)
print(df)

# %%
import pandas as pd
students = pd.read_csv("All Data Sets/06_Data_Set_students.csv")
students

# %%
# inner Join 
dec = pd.read_csv("All Data Sets/05_Data_Set_reg-month2.csv")
students = pd.read_csv("All Data Sets/06_Data_Set_students.csv")
df = students.merge(dec, how="inner", on="student_id")
print(df)

# %%
import pandas as pd
import numpy as np
course = pd.read_csv("All Data Sets/01_DataSet_courses.csv")
nov = pd.read_csv("All Data Sets/04_Data_Set_reg-month1.csv")
dec = pd.read_csv("All Data Sets/05_Data_Set_reg-month2.csv")
df = course.merge(dec, how="left", on="course_id")
print(df)
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        12.0
# 1           1            python   2499        14.0
# 2           1            python   2499        38.0
# 3           2               sql   3499         7.0
# 4           3     data analysis   4999        16.0
# 5           4  machine learning   9999        14.0
# 6           5           tableau   2499         3.0
# 7           5           tableau   2499        12.0
# 8           5           tableau   2499         2.0
# 9           5           tableau   2499        22.0
# 10          5           tableau   2499        23.0
# 11          6          power bi   1899        14.0
# 12          6          power bi   1899         7.0
# 13          6          power bi   1899        22.0
# 14          7          ms sxcel   1599        16.0
# 15          7          ms sxcel   1599         7.0
# 16          7          ms sxcel   1599        12.0
# ...
