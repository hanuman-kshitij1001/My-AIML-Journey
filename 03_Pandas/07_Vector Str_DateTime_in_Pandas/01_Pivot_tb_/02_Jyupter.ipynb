# %%
import numpy as np
import pandas as pd
import seaborn as sns
df = sns.load_dataset('tips')
# df
result = df.groupby('sex',observed=True)[['total_bill']].mean()
print(result)

result = df.groupby(['sex','smoker'])[['total_bill']].mean()
print(result)

result = df.groupby(['sex','smoker'])[['total_bill']].mean().unstack()
print(result)

result = df.pivot_table(index='sex',columns='smoker',values='total_bill', observed=True)
print(result)
# Out:
#         total_bill
# sex
# Male     20.744076
# Female   18.056897
#                total_bill
# sex    smoker
# Male   Yes      22.284500
#        No       19.791237
# Female Yes      17.977879
#        No       18.105185
#        total_bill
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185
# C:\Users\acer\AppData\Local\Temp\ipykernel_26224\1936461962.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   result = df.groupby(['sex','smoker'])[['total_bill']].mean()
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python314\python.exe
