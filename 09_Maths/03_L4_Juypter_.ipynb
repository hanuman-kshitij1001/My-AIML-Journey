# %%
# How TO Use PDF in Data-Science
# Haam Yaha pe Iris data set pe kaam karne wale hai

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import seaborn as sns
#
# File ~\OneDrive\Desktop\My_AIML_Journey\.venv\Lib\site-packages\pandas\__init__.py:32
#      29         _missing_dependencies.append(f"{_dependency}: {_e}")
#      31 if _missing_dependencies:  # pragma: no cover
# ---> 32     raise ImportError(
#      33         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      34     )
#      35 del _hard_dependencies, _dependency, _missing_dependencies
#      37 try:
#      38     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
# df1 = pd.read_csv("All_Data_Set/Iris.csv")
# df1

# %%
df2 = sns.load_dataset('iris')
df2.head()

# %%
sns.kdeplot(df2["sepal_length"])

# %%
df2.head(60)

# %%
sns.kdeplot(data = df2 , x="sepal_length", hue = "species")

# %%
sns.kdeplot(data= df2, x='sepal_width', hue = 'species')

# %%
sns.kdeplot(data=df2, x='petal_length', hue = 'species')

# %%
sns.kdeplot(data=df2, x='petal_width', hue='species')

# %%
# Note = Kyu Banay Hia Maine 3 Graph Aur Esse kya hun Mai Batata 
#  Sabse Pahli baat Bhai maine Sabko Ek ek Karke plot kar ke dekh liya done 
# Maine dekha ki Sepal Length aur pedal width me mai ye distinguest kar pa raha hun ki kaha se data diff kar raha hai toh esse hi 
# plot karn asikhna , plot karke

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic

# %%
# Code here

# %%
sns.kdeplot(data=titanic, x ='Age', hue='Survived')

# %%
sns.kdeplot(data=titanic[titanic["Survived"] == 0], x="Age", label="Not Survived")
sns.kdeplot(data=titanic[titanic["Survived"] == 1], x="Age", label="Survived")

# %%
print(titanic.columns)

# %%
# Ab Haam Dekhte hia Kaise CDs use Karte hai 
# CDS Uss Point tak ka sara problablity de deta hai

# %%
sns.kdeplot(data=df2, x='petal_width', hue='species')
sns.ecdfplot(data=df2, x='petal_width', hue='species')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.kdeplot(data=df2, x='petal_width', hue='species')
#       2 sns.ecdfplot(data=df2, x='petal_width', hue='species')
#
# NameError: name 'sns' is not defined

# %%
# Ab Dekhte hai aap CDF ko Kaise Analize kar sakte ho

# %%
# 2-D Density Plot

# %%
sns.jointplot(data=df2, x= 'petal_length', kind='kde', fill=True, cbar=True, )

# %%
# Skewness
# Sari Defination maine Notes me likh di hai 
# Done Han Ok

# %%
# Chalo Plot karke dekhte hai esse

# %%
titanic['Age'].skew()

# %%
df2["petal_length"].skew()
