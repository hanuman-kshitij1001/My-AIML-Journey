# %%
import requests  # Esse haam htpp req karte using python
import pandas as pd

# %%
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=9c3510b4224a5c362c701d95238b950d')
# Output <Response [200]> server Conected sucseefully

# %%
response

# %%
response.json()

# %%
movies_reult = response.json()['results']
movies_reult
# Ye Kaya karega Esse shirf result ko dikhayega

# %%
df = pd.DataFrame(movies_reult)
df
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /5lTZyuBTNOfawsfPT8Q0cIg6qAF.jpg                 [27, 53]  1339713
# 1   False  /laR2dpcNpbv83jdlRUNAYPPjH90.jpg             [28, 14, 12]   931285
# 2   False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg              [10402, 18]   936075
# 3   False  /oPsRr7AfNLw6XaPuMpvkWK0bIUA.jpg                 [28, 18]  1057265
# 4   False  /1eAuwNBy34kkM3xkl202z4f1NiI.jpg                 [28, 14]  1367220
# 5   False  /7uXzE0ZBkbAeKylOz7cUQF4Yw75.jpg                     [18]   879945
# 6   False  /l5QgEvlfK6eHPM4YPEk7AArXmh8.jpg              [10749, 35]  1308553
# 7   False  /s6ly8laenkHWlIBRkLSfIuEMLC6.jpg          [53, 878, 9648]  1275779
# 8   False  /A2tzVTVtnTvpji96IZmleN78KKv.jpg                 [27, 35]  1239134
# 9   False  /9Z2uDYXqJrlmePznQQJhL6d92Rq.jpg  [10751, 35, 12, 14, 16]  1226863
# 10  False  /6zg7A9ICOthNR2TSXlT51KvXrsA.jpg            [28, 12, 878]  1228710
# 11  False  /emK2hOB6ACiExT0lNLog9lAmMFL.jpg              [18, 10749]  1226293
# 12  False                              None                     [18]  1604143
# 13  False  /l1nekhf05HS5OpBr0vRqcD3NxoS.jpg         [36, 80, 28, 14]  1103473
# 14  False  /1x9e0qWonw634NhIsRdvnneeqvN.jpg              [10749, 18]  1523145
# 15  False  /krhj4Fhb0G3QCmyBtEADxgFFmRX.jpg              [18, 10749]    11012
# 16  False  /xugEpZk9YQ0DIz1aFvH5HGkqpZK.jpg               [27, 9648]  1304313
# 17  False  /jPr9Id0f3knF82ETEBGPpMhXj4M.jpg                 [80, 53]   912378
# 18  False  /piV2OnzTZCyGBP9JCjlHIgKGlfo.jpg            [28, 14, 878]   454639
# 19  False  /ew3EqF9VLTxmK64OsHT7p7lr4wT.jpg                 [28, 80]  1280738
#
#                            title original_language  \
# 0                      Obsession                en
# 1               Mortal Kombat II                en
# 2                        Michael                en
# 3                          Peddi                te
# 4                        Karuppu                ta
# 5                The Unknown Man                nl
# 6   Hai Jawani Toh Ishq Hona Hai                hi
# 7                 Disclosure Day                en
# 8                  Bhooth Bangla                hi
# 9   The Super Mario Galaxy Movie                en
# 10     The Mandalorian and Grogu                en
# 11                       Salitan                tl
# 12                   나는 신혼 너는 재혼                ko
# 13                KD – The Devil                kn
# 14     Your Heart Will Be Broken                ru
# 15                        Damage                en
# 16        Lee Cronin's The Mummy                en
# 17                        Dridam                ml
# 18       Masters of the Universe                en
# 19                   The Furious                en
#
#                   original_title  \
# 0                      Obsession
# 1               Mortal Kombat II
# 2                        Michael
# 3                         పెద్ది
# 4                        கருப்பு
# 5                L'homme inconnu
# 6       है जवानी तो इश्क होना है
# 7                 Disclosure Day
# 8                      भूत बंगला
# 9   The Super Mario Galaxy Movie
# 10     The Mandalorian and Grogu
# 11                       Salitan
# 12                   나는 신혼 너는 재혼
# 13              ಕೆಡಿ - ದಿ ಡೆವಿಲ್
# 14     Твоё сердце будет разбито
# 15                        Damage
# 16        Lee Cronin's The Mummy
# 17                          ദൃഢം
# 18       Masters of the Universe
# 19                           火遮眼
#
#                                              overview  popularity  \
# 0   After breaking the mysterious "One Wish Willow...    617.3077
# 1   The fan favorite champions—now joined by Johnn...    536.6859
# 2   The story of Michael Jackson, one of the most ...    512.4438
# 3   In 1980s rural Andhra Pradesh, a spirited vill...    361.9352
# 4   In a world where justice falters, guardian dei...    413.7865
# 5   Louis, a Flemish writer, decides to isolate hi...    378.8827
# 6   When Jass leaves his marriage over conflicting...    289.6886
# 7   If you found out we weren’t alone, if someone ...    326.4035
# 8   A man inherits a palace in rural Mangalpur and...    337.3635
# 9   Having thwarted Bowser's previous plot to marr...    243.6128
# 10  The evil Empire has fallen, and Imperial warlo...    239.2479
# 11  A suspicious wife follows her husband in Bali....    231.5883
# 12                                                       274.1095
# 13  In the early 1970s, a petty criminal Kaali unw...    207.3802
# 14  High school student Polina is saved from bully...    254.0422
# 15  The life of a respected British politician at ...    184.6617
# 16  The young daughter of a journalist disappears ...    168.1853
# 17  A police officer arrives at a seemingly peacef...    175.7922
# 18  After being separated for 15 years, the Sword ...    152.4585
# 19  After Wang Wei's daughter is kidnapped by a cr...    173.2088
#
#                          poster_path release_date  softcore  video  \
# 0   /bRwnj8WEKBCvmfeUNOukJPwB43K.jpg   2026-05-13     False  False
# 1   /hwRdDFIhaEmpRgoki805YvyyjZf.jpg   2026-05-06     False  False
# 2   /zm0KAbOjlt9eR5y7vDiL2dEOwMl.jpg   2026-04-22     False  False
# 3   /kJAJNNBYlbqAcpTDxBNnaILSMTy.jpg   2026-06-03     False  False
# 4   /4KZXlZ5tTT6ghbW77gS4hSLkCd7.jpg   2026-05-14     False  False
# 5   /4TpBhdaSl5ALHbgeaYOLF8Q3haz.jpg   2021-10-16     False  False
# 6   /vmlJvz6qVzYgei2V74GvnmcuQfW.jpg   2026-06-04     False  False
# 7   /3o5YPjDGDTcTDL5ftDA9NwN9dLd.jpg   2026-06-10     False  False
# 8   /79RBp8afL4u4z3nVGR78z6eIvBB.jpg   2026-04-16     False  False
# 9    /eJGWx219ZcEMVQJhAgMiqo8tYY.jpg   2026-04-01     False  False
# 10  /5Vi8dSauVwH1HOsiZceDMbRr1Ca.jpg   2026-05-20     False  False
# 11  /rMgG7cWuq9O6zhhLs2CbqIKVA8V.jpg   2024-02-16     False  False
# 12  /wTFF1SFTDYL7M1yWjY0K8Ga5pZS.jpg   2021-08-12     False  False
# 13  /nEuEMJrnLBneE9tJlmzbhCFLu95.jpg   2026-04-30     False  False
# 14  /7wIBfBl2gejt6xHxNSK0reVIm7E.jpg   2026-03-26     False  False
# 15  /alf3JOPP7EYP0iO24gwe5YfRnqo.jpg   1992-12-02     False  False
# 16  /1q308iixueCU4pFtSYugNOevtNx.jpg   2026-04-15     False  False
# 17  /fXSdAujfiRRW6LqekN4FvFQidh3.jpg   2026-05-08     False  False
# 18  /3YMd9Ogae4rDKLWuAZFuse9xhc5.jpg   2026-06-03     False  False
# 19  /zP19YO60jwEsfKd5Qf1UvA5uJu8.jpg   2026-06-10     False  False
#
#     vote_average  vote_count
# 0          7.913         817
# 1          7.987        1427
# 2          8.650        2567
# 3          6.547          43
# 4          7.059          17
# 5          7.800           9
# 6          5.471          17
# 7          6.778         481
# 8          5.500          20
# 9          8.193        2654
# 10         6.766         481
# 11         4.714           7
# 12         0.000           0
# 13         7.500           2
# 14         6.913          92
# 15         6.600         689
# 16         8.048        1861
# 17         7.000           1
# 18         7.300         236
# 19         8.100          39

# %%
# Ab yaha Jo J o mujeh Chahiye Hia Uss emai Nikal Luga 
jo_chahiye = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity','vote_average', 'vote_count']]
# Out:
#          id                         title  \
# 0   1339713                     Obsession
# 1    931285              Mortal Kombat II
# 2    936075                       Michael
# 3   1057265                         Peddi
# 4   1367220                       Karuppu
# 5    879945               The Unknown Man
# 6   1308553  Hai Jawani Toh Ishq Hona Hai
# 7   1275779                Disclosure Day
# 8   1239134                 Bhooth Bangla
# 9   1226863  The Super Mario Galaxy Movie
# 10  1228710     The Mandalorian and Grogu
# 11  1226293                       Salitan
# 12  1604143                   나는 신혼 너는 재혼
# 13  1103473                KD – The Devil
# 14  1523145     Your Heart Will Be Broken
# 15    11012                        Damage
# 16  1304313        Lee Cronin's The Mummy
# 17   912378                        Dridam
# 18   454639       Masters of the Universe
# 19  1280738                   The Furious
#
#                                              overview release_date  \
# 0   After breaking the mysterious "One Wish Willow...   2026-05-13
# 1   The fan favorite champions—now joined by Johnn...   2026-05-06
# 2   The story of Michael Jackson, one of the most ...   2026-04-22
# 3   In 1980s rural Andhra Pradesh, a spirited vill...   2026-06-03
# 4   In a world where justice falters, guardian dei...   2026-05-14
# 5   Louis, a Flemish writer, decides to isolate hi...   2021-10-16
# 6   When Jass leaves his marriage over conflicting...   2026-06-04
# 7   If you found out we weren’t alone, if someone ...   2026-06-10
# 8   A man inherits a palace in rural Mangalpur and...   2026-04-16
# 9   Having thwarted Bowser's previous plot to marr...   2026-04-01
# 10  The evil Empire has fallen, and Imperial warlo...   2026-05-20
# 11  A suspicious wife follows her husband in Bali....   2024-02-16
# 12                                                      2021-08-12
# 13  In the early 1970s, a petty criminal Kaali unw...   2026-04-30
# 14  High school student Polina is saved from bully...   2026-03-26
# 15  The life of a respected British politician at ...   1992-12-02
# 16  The young daughter of a journalist disappears ...   2026-04-15
# 17  A police officer arrives at a seemingly peacef...   2026-05-08
# 18  After being separated for 15 years, the Sword ...   2026-06-03
# 19  After Wang Wei's daughter is kidnapped by a cr...   2026-06-10
#
#     popularity  vote_average  vote_count
# 0     617.3077         7.913         817
# 1     536.6859         7.987        1427
# 2     512.4438         8.650        2567
# 3     361.9352         6.547          43
# 4     413.7865         7.059          17
# 5     378.8827         7.800           9
# 6     289.6886         5.471          17
# 7     326.4035         6.778         481
# 8     337.3635         5.500          20
# 9     243.6128         8.193        2654
# 10    239.2479         6.766         481
# 11    231.5883         4.714           7
# 12    274.1095         0.000           0
# 13    207.3802         7.500           2
# 14    254.0422         6.913          92
# 15    184.6617         6.600         689
# 16    168.1853         8.048        1861
# 17    175.7922         7.000           1
# 18    152.4585         7.300         236
# 19    173.2088         8.100          39

# %%
df = pd.DataFrame() 
# step 2: mai ab ek Loop Chala raha hun 
for i in range(1, 429):
    # har baar loop ke ander mai es url pe hi karunga 
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=9c3510b4224a5c362c701d95238b950d&language=en-US&page={}'.format(i))   # matlb jo bhi i ka value honga wahi mera page number honga theek 
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity','vote_average', 'vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)
