# %%
import pandas as pd

# %%
import random

# %%
L = []
for i in range(1000):
    L.append(random.randint(1, 6))

# %%
len(L)

# %%
print(L[:5])

# %%
L[:5]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index ()

# %%
s

# %%
s.plot(kind='bar')

# %%
# Haam Log Ek Sath DO Dice Role Kar raha hun Theek hai na Ok

L = []
for i in range(1000):
    a = random.randint(1,6)
    b = random.randint(1,6)

    L.append(a+b)

# %%
s = (pd.Series(L).value_counts()/ pd.Series(L).value_counts().sum()).sort_index()

# %%
s

# %%
s.plot(kind='bar')

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

sample = normal(loc=50, scale=5, size=1000)

# %%
sample

# %%
sample.mean()

# %%
# Ab Haam Ek histo polt karenge jisse hame pata chaelga ki data kaisa hai like normal ya kuch aur
plt.hist(sample, bins=10)

# %%
sample_mean = sample.mean()
sample_std = sample.std()

# %%
from scipy.stats import norm
dist = norm(sample_mean, sample_std)

# %%
values = np.linspace(sample.min(), sample.max(), 100)

# %%
sample.min()

# %%
sample.max()

# %%
probabili_den = [dist.pdf(value) for value in values]

# %%
#Haam plot karunga 
plt.hist(sample, bins=10, density=True)
plt.plot(values, probabili_den)

# %%
# Ab Ye Kaam Asasni se kar pate hai agr seborn use kiya hota toh 
import seaborn as sns
sns.distplot(sample)

# %%
# generate a sample
sample1 = normal( loc = 20, scale=5, size=300)
sample2 = normal(loc=40, scale= 5, size =700)
sample  = np.hstack((sample1, sample2))

# %%
sample

# %%
#Plot histogram bins = 50

# %%
from sklearn.neighbors import KernelDensity
model = KernelDensity(bandwidth=3, kernel='gaussian')
