# %% [markdown]
# ## ****Batch Gradient_Descent Lecture_2****

# %% [markdown]
# ****Batch gradient descent is an optimization algorithm in machine learning that calculates the gradient of the cost function using the entire training dataset at once to update model****

# %% [markdown]
# ## ****Hame Ye Sari CHeeze Yani YE sare Types ke GD Padhna hai****

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ___

# %% [markdown]
# * Jo Hame Pahele Padha tha wo bahut Slow hota hai

# %% [markdown]
# ***Note - Batch GDis Very rear Because of***
# * Its is Specially use in convex Function
# * Convext FUnction Honga toh Hi Usme Batch Gra Use kiya Ja Sakta Hia
# * Usme bhi EK Sarth Hai
# * Data Bahut Bada nahi Hona Chhiaye kyuki Usse Calculation Nahi ho pata hai
#
# * Yaha pe Haam Batch Gra padhne More Then 2-D Data

# %% [markdown]
# ___

# %% [markdown]
# ## ****Mathmatical Formulation For Batch Gradiant****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ****We Have to Move the finding Loosfunction derivates With respect to B not function****

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# * ****Ab Mai Man Ke chal Raha Hun Mere pass N rows hai****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ****Again going to Calculate Second Loss Fuction With respect to Beta one****

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ___

# %% [markdown]
# ### ****COMPLETE THEORY PART****
# ___
