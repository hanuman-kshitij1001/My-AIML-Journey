# %% [markdown]
# # ****What are the main Assumptions of Linear Regression? | Top 5 Assumptions of Linear Regression****

# %% [markdown]
# ### ****Jo Eska Answer Wagera Nahi De pate hai Unko Judge bhi Kiya jata hai Esse****

# %% [markdown]
# <div style="background: #181825; color: #cdd6f4; padding: 28px 32px; border-radius: 14px; border: 1px solid #313244; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; box-shadow: 0 8px 24px rgba(0,0,0,0.45); max-width: 760px; margin: auto;">
#
#   <!-- Header -->
#   <div style="border-bottom: 2px solid #313244; padding-bottom: 14px; margin-bottom: 22px;">
#     <h2 style="color: #f9e2af; margin: 0 0 4px 0; font-size: 24px; font-weight: 700; letter-spacing: 0.5px;">
#       Assumptions of Linear Regression
#     </h2>
#     <span style="color: #6c7086; font-size: 13px; font-weight: 500;">
#       Core prerequisites for trustworthy OLS predictions
#     </span>
#   </div>
#
#   <!-- Assumption Cards List -->
#   <div style="display: flex; flex-direction: column; gap: 12px;">
#     <!-- 1. Linear Relationship -->
#     <div style="display: flex; align-items: center; background: #1e1e2e; padding: 14px 18px; border-radius: 10px; border-left: 5px solid #89b4fa;">
#       <span style="background: rgba(137, 180, 250, 0.15); color: #89b4fa; font-weight: 800; font-size: 15px; width: 32px; height: 32px; border-radius: 8px; display: flex; align-items: center; justify-content: center; margin-right: 16px; flex-shrink: 0;">1</span>
#       <div>
#         <div style="color: #fab387; font-weight: 700; font-size: 16px;">Linear Relationship between input and output</div>
#         <div style="color: #a6adc8; font-size: 13px; margin-top: 2px;">Independent features aur target variable ke beech relationship straight line honi chahiye.</div>
#       </div>
#     </div>
#     <!-- 2. No Multicollinearity -->
#     <div style="display: flex; align-items: center; background: #1e1e2e; padding: 14px 18px; border-radius: 10px; border-left: 5px solid #a6e3a1;">
#       <span style="background: rgba(166, 227, 161, 0.15); color: #a6e3a1; font-weight: 800; font-size: 15px; width: 32px; height: 32px; border-radius: 8px; display: flex; align-items: center; justify-content: center; margin-right: 16px; flex-shrink: 0;">2</span>
#       <div>
#         <div style="color: #fab387; font-weight: 700; font-size: 16px;">No Multicollinearity</div>
#         <div style="color: #a6adc8; font-size: 13px; margin-top: 2px;">Input features aapas me heavily correlated nahi hone chahiye (VIF score should be low).</div>
#       </div>
#     </div>
#     <!-- 3. Normality of Residual -->
#     <div style="display: flex; align-items: center; background: #1e1e2e; padding: 14px 18px; border-radius: 10px; border-left: 5px solid #f9e2af;">
#       <span style="background: rgba(249, 226, 175, 0.15); color: #f9e2af; font-weight: 800; font-size: 15px; width: 32px; height: 32px; border-radius: 8px; display: flex; align-items: center; justify-content: center; margin-right: 16px; flex-shrink: 0;">3</span>
#       <div>
#         <div style="color: #fab387; font-weight: 700; font-size: 16px;">Normality of Residual</div>
#         <div style="color: #a6adc8; font-size: 13px; margin-top: 2px;">Model ke error terms (residuals) Normal Distribution (bell curve) follow karne chahiye.</div>
#       </div>
#     </div>
#     <!-- 4. Homoscedasticity -->
#     <div style="display: flex; align-items: center; background: #1e1e2e; padding: 14px 18px; border-radius: 10px; border-left: 5px solid #cba6f7;">
#       <span style="background: rgba(203, 166, 247, 0.15); color: #cba6f7; font-weight: 800; font-size: 15px; width: 32px; height: 32px; border-radius: 8px; display: flex; align-items: center; justify-content: center; margin-right: 16px; flex-shrink: 0;">4</span>
#       <div>
#         <div style="color: #fab387; font-weight: 700; font-size: 16px;">Homoscedasticity</div>
#         <div style="color: #a6adc8; font-size: 13px; margin-top: 2px;">Residuals ka variance poore data spread me constant hona chahiye (koi cone/fan pattern nahi).</div>
#       </div>
#     </div>
#     <!-- 5. No Autocorrelation of Errors -->
#     <div style="display: flex; align-items: center; background: #1e1e2e; padding: 14px 18px; border-radius: 10px; border-left: 5px solid #f38ba8;">
#       <span style="background: rgba(243, 139, 168, 0.15); color: #f38ba8; font-weight: 800; font-size: 15px; width: 32px; height: 32px; border-radius: 8px; display: flex; align-items: center; justify-content: center; margin-right: 16px; flex-shrink: 0;">5</span>
#       <div>
#         <div style="color: #fab387; font-weight: 700; font-size: 16px;">No Autocorrelation of Errors</div>
#         <div style="color: #a6adc8; font-size: 13px; margin-top: 2px;">Ek error point doosre error point par depend nahi hona chahiye (Independent observations).</div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Bottom Pro-Tip Footer -->
#   <div style="margin-top: 18px; background: #11111b; padding: 10px 16px; border-radius: 8px; border: 1px dashed #45475a; font-size: 12.5px; color: #9399b2; text-align: center;">
#     Agar yeh assumptions satisfy nahi hote, toh Linear Regression ke coefficients aur p-values unreliable ban jaate hain.
#   </div>
#
# </div>

# %% [markdown]
# ## ******Sir ki Notes******

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ____

# %% [markdown]
# ##  ****1- Linear Relationship****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Sabse pehle LR perform karne ke liye jo aapko sabse pehla assumption chahiye wo yeh hai ki aapke data me:
#
#
# * Aapke data me Linear Relationship hona chahiye, input aur output (target) me linear relationship hona chahiye.
#
#
# * Jaise pehle graph me positive linear relationship dekh rahe ho.
#
#
# * Second me negative linear relationship hai.
#
#
# * Third me not a linear relationship (curved/non-linear) hai.

# %% [markdown]
# * Maan lo aapke paas multiple input columns hain, tab bhi aapke har ek individual input feature ka output (target) ke sath linear relationship hona hi chahiye.

# %% [markdown]
# ___

# %% [markdown]
# ## ******2. No Multicollinearity:******
#
#
# * Yahan pe hum dekhte hain ki aapke system me koi bhi multicollinearity nahi honi chahiye, aur sub col ek dusre  me nahi honi chahiye.
#
#
# * **Multicollinearity ka simple matlab:** Yahan pe jitne bhi input columns honge, unke aapas ke beech mein koi strong relation nahi hona chahiye—bas yahi simple concept hai.
#
# * Lekin Input columns ka Output ($Y$) ke sath accha relation hona chahiye (Linear Relationship).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ___

# %% [markdown]
# ## ****3- Normal Residual****

# %% [markdown]
# * Ye Part hamre Residual pe depend karte hai matlb Error pe

# %% [markdown]
# #### ****Toh Ab Ao Samjh Lete hai ki LR ke Case Me Ye Error Kya hota hai****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Yaha pe line Ye rep kar raha hai kar raha hai ki Ye point ke liye pridcation Hona kuch aur chhihiya tha but ho kuch aur raha hai

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Yaha pe jo Diffrence hai na Esse Hi bola Jata hai Error

# %% [markdown]
# #### ****Note- Hamre jo Ab Age assumption hai Na wo Inhi Error pe Depend karte hai****

# %% [markdown]
# ___

# %% [markdown]
# ## ****4. Homoscedasticity****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ****Kaise Nikalte hai****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * matlb ries ko y axis pe rakho aur Y pred ko y pe

# %% [markdown]
# ___
