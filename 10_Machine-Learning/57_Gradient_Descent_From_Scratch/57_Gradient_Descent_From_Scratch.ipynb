# %% [markdown]
# ## ****Gradient Desecent From Scrach****

# %% [markdown]
# * ****Gradient descent is a first-order iterative optimization algorithm for finding a local minimum of a differentiable function. The idea is to take repeated steps in the opposite direction of the gradient (or approximate gradient) of the function at the current point, because this is the direction of steepest descent. Conversely, stepping in the direction of the gradient will lead to a local maximum of that function; the procedure is then known as gradient ascent.****

# %% [markdown]
# ####  ****In Short -****
# ****GD Is An Algo Jisko Aap Koi Bhi Function Dete Ho Bass Wo Diffrentiable hona chhaiye****
# * ****toh Waha pe GD Apko Minima Nikal Ke Deta hai****
# * ****toh ye minima nikalne ki Techniques hai****
# * ****kya GD shirf LR pe apply Hota hai bikul Nahi****
# * ****Is a Genaral Algorithm Bahut jagha use hota hai****
# * ****Ye Pure DL ka Backbone hai****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ____

# %% [markdown]
# ## ******Intution Of this Algorithm******

# %% [markdown]
# * ****Maine Ek Data Set liya Hai 2 col aur 4 rows ka****
# * ****Mujhe ab Ek Line Draw Karna Hia ek Fit line theek****
# * ****Best fit line wo Line Hota hai jo Y axis ki Direction Me Bahut kaam Galti kare****
# * ****Matlb actual Y aur aur Uske Y ka Squre ka sum bahut kaam ana chhahiye****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * ****Jab aap L aur B me Graph Plot karoge toh Kuch essa Value Ka Graph Banega****

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * ****? Yahi Jagha Hai jaha pe B ka Value Minimum Hai AUr Mujhe B ka Minimum Value hi chhhaiye****

# %% [markdown]
# ### ****Now We Are Moving Here to the Steps of GD Mean How Can We Find Lets See In Steps****

# %% [markdown]
# * ****step -1  Select a random b****
# * ****Let b = -10 select any random value****
# * ****Aproch ye hai ki apke do option ahi ya toh aap B ko Badha ke Minima nikalo ya fhir B ko Ghata ke minima Nikalo****
# * ****Par Kaise kya karna hai****
# * ****`Note` - yahi ess algorithm ka trick hai****
# * ****Toh apko Eska answer Slop Me Milega****

# %% [markdown]
# * ****Ap Jaha pe bhi ho Waha ka Slop Nikloge****
# * ****Apko Uss jagha ka Diffr karna honga****
# * ****Aur Diffr ke liye mujhe Equation chhiaye esliye bolte hai GD wahi lagta hai jaha pe Function Diff hota hai****

# %% [markdown]
# * ****Ab Hamne Slop Nikal Liya toh Slop Ka Diretion apko Guide karta hai apko kaka pe jana hai****
# * ****Agr Apko Slop Negative hai Eska Matlb apko Age jana Hai****
# * ****Agr apka slop Postive hai eska matlb apko piche jana hai****
# * ****B(new) = B(old) - Slope****

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ___

# %% [markdown]
# ## ****Mathmatical Formulation****

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### ****Few Dicussion****

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
