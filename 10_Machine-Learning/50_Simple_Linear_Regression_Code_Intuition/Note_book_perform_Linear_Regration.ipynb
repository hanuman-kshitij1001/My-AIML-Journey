# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("placement.csv")

# %%
df.head(10)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (in LPA)')
plt.title('CGPA vs Package')
# Out:
# Text(0.5, 1.0, 'CGPA vs Package')

# %% [markdown]
# ### ****From Now We Are Applyling our Algorithm and Create a model Jisko Haam Agr Input me CGPA Dun toh wo predict Kar sake done****

# %% [markdown]
# * **Yaha pe haam apna X col aur Y col Alag Alag Karne wale hai**

# %% [markdown]
# * ****Step 1****

# %%
x = df.iloc[:,0:1]
y = df.iloc[:, -1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %% [markdown]
# * ****Step 2****

# %% [markdown]
# ***Genrally Yaha pe Hub ab apne train test ko Split karte hai to Haam Yah do Part data ko divide karunga***

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ***Now Eska Haam Ab Object banane Wale hai Bro***

# %%
lr = LinearRegression()

# %% [markdown]
# ****Now es object ke pass kuch methodes aur Attributes hai jo Haam Use karne wale hai****

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93
# 115  8.35
# 69   7.30
# 170  6.22
# 174  7.32
# 45   7.87
# 66   5.11
# 182  5.88
# 165  8.21
# 78   6.59
# 186  7.84
# 177  7.09
# 56   5.84
# 152  7.37
# 82   5.58
# 68   7.56
# 124  6.06
# 16   6.84
# 148  7.57
# 93   6.79
# 65   7.60
# 60   5.61
# 84   4.26
# 67   6.51
# 125  7.33
# 132  5.84
# 9    8.31
# 18   6.94
# 55   8.20
# 75   6.97
# 150  6.30
# 104  7.62
# 135  6.10
# 137  7.14
# 164  9.06
# 76   6.94

# %%
y_test
# Out:
# 95     2.79
# 15     3.23
# 30     3.26
# 158    3.04
# 128    3.34
# 115    4.21
# 69     2.94
# 170    2.87
# 174    2.99
# 45     3.58
# 66     1.63
# 182    2.08
# 165    4.08
# 78     2.21
# 186    3.47
# 177    3.64
# 56     2.74
# 152    3.08
# 82     2.17
# 68     2.99
# 124    2.31
# 16     2.35
# 148    3.40
# 93     3.08
# 65     3.81
# 60     2.19
# 84     1.53
# 67     2.89
# 125    3.16
# 132    2.48
# 9      3.51
# 18     2.98
# 55     3.39
# 75     3.28
# 150    2.73
# 104    3.74
# 135    2.60
# 137    3.13
# 164    3.82
# 76     3.15
# Name: package, dtype: float64

# %% [markdown]
# ***Yaha pe Haam test kar Rahe Hai Value Daal Ke Matlb Ki Haam X_test se value nikal ke Esse de rahe Hai Aur Target Y_test se Matach kar rahe hai***

# %%
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.1995207])

# %% [markdown]
# ***Mai Yaha pe Apko Ek Chez Dikhta hun Sach me LinearRegression Kaam Karte Waqt Ek Line Draw Kiya Hai Jo mai Tumhe Show Karta hun ab***

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %% [markdown]
# ***Boss apke Linear Regration Ka Line Hia aur Yahi Fit Point hai***

# %% [markdown]
# ****Ab Mai Apko *******Y = Mx + C******* , M slop kasie Nikalna aur C kaise Nikalte hai****

# %%
M = lr.coef_
M
# Out:
# array([0.57425647])

# %%
C = lr.intercept_
C
# Out:
# np.float64(-1.0270069374542108)

# %% [markdown]
# ****Y = Mx+C  yaha pe ap ko Y mill Raha hai That is Your Package esse hi Nikal Raha Hai yaha pe****

# %%
Y = m*8.58+C
Y  # yaha pe wahi prectict ho raha hai bass ye dikh nahi raha hai but intution yahi hai

# %% [markdown]
# ___
