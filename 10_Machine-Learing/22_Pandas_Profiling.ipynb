# %% [markdown]
# # Day 22 — Pandas Profiling
#
# Pandas Profiling / YData Profiling automatically generates an EDA report.
#
# It can provide:
#
# - Dataset overview
# - Variable statistics
# - Missing values
# - Duplicate rows
# - Correlations
# - Distributions
# - Warnings

# %%
# Install if required:
# pip install ydata-profiling

# %%
# from ydata_profiling import ProfileReport

# df = pd.read_csv("data.csv")

# profile = ProfileReport(
#     df,
#     title="EDA Report"
# )

# profile.to_notebook_iframe()

# %% [markdown]
# ## When to use profiling?
#
# Useful during initial exploration.
#
# But do not blindly depend on automated reports.
#
# You still need to understand:
#
# - business problem
# - target variable
# - data quality
# - leakage
# - feature meaning
