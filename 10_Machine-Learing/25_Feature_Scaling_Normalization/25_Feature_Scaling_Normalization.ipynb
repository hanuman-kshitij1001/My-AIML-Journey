# %% [markdown]
# # ***Normalization in Feature Scaling***
#
# Pichli class me humne Feature Scaling ki pehli technique **Standardization** ko detail me complete kar liya tha.
#
# Aaj hum Feature Scaling ki dusri sabse important technique dekhne wale hain, jise **Normalization** kaha jata hai.
#
# ---
#
# ### ***Agenda for Today***
# * **What is Normalization?** (Core Intuition & Definition)
# * **Types of Normalization Techniques:**
#   1. Min-Max Scaling (Most Popular)
#   2. Mean Normalization
#   3. MaxAbs Scaling
#   4. Robust Scaling (Handling Outliers)
# * **Scikit-Learn Implementation:** Python code ke through dataset par implement karke before & after distributions ko visualize karenge.

# %% [markdown]
# ### ***Definition of Normalization-:***
#
# > **Normalization** Machine Learning me data preparation ka ek important step hota hai. Iska main goal dataset ke numerical columns ki values ko ek **common scale (usually 0 to 1)** me transform karna hota hai, bina unke beech ke relative differences (proportions) ko distort kiye ya data ki information loose kiye.

# %% [markdown]
# ## ***Simpler Terms me Normalization ka Real-world Intuition***
#
# Maan lete hain hum ek aise dataset par kaam kar rahe hain jisme hamare paas do input features hain:
# * <span style="color: #2b6cb0; font-weight: bold;">Height</span> (e.g., in centimeters / feet)
# * <span style="color: #2b6cb0; font-weight: bold;">Weight</span> (e.g., in kilograms / grams)
#
# Aur hamara task predict karna hai ki <span style="color: #d69e2e; font-weight: bold;">kya wo person specific sports equipment khareedega ya nahi?</span>
#
# ---
#
# #### 1. Numerical Quantities ka Core Concept: Magnitude vs Units
# Kisi bhi numerical measurement ke andar **do cheezein** hoti hain:
# 1. **Magnitude (Numeric Value):** E.g., `70`, `70,000`
# 2. **Unit (Measurement Scale):** E.g., `kg`, `grams`, `tonnes`
#
# Agar ek dataset me weight **$70 \text{ kg}$** likha hai aur dusre me wahi weight **$70,000 \text{ grams}$** likha hai, toh numeric magnitude zameen-aasman ka fark create kar deta hai, jabki physical value bilkul same hai.
#
# ---
#
# #### 2. ML Models ke sath Problem (Kyun Units lafda karti hain?)
# Machine Learning algorithms ko **units ka matlab samajh nahi aata**; algorithms sirf raw numbers (magnitudes) ko dekhte hain:
# * Agar unit **Grams ($70,000$)** hui, toh algorithm use bohot badi aur high-priority value maan lega.
# * Agar unit **Kg ($70$)** hui, toh wo comparison me bohot chhota lagega.
#
# ---
#
# #### 3. The Core Idea Behind Normalization
# > **The Golden Rule in ML:** <span style="color: #c53030; font-weight: bold;">***Units ko eliminate karo aur sirf pure magnitude ko ek common scale par lekar aao.***</span>
#
# * Normalization ka main purpose dataset se **units ke difference ko hata kar** sabhi features ko ek common bounded range (jaise **$0$ to $1$**) me lana hota hai.
# * Jab sabhi numerical features unit-free aur common scale par aa jate hain, tab Machine Learning models **biased hue bina consistent aur accurate results** dete hain.

# %% [markdown]
# ## <span style="color: #2b6cb0;">***Types of Normalization Techniques***</span>
#
# Machine Learning me Normalization ki kai techniques hoti hain. Agar hum **Scikit-Learn (sklearn)** ke official documentation ko dekhein, toh wahan kai tarah ke transformations available hain.
#
# Lekin hum mainly in **4 most important techniques** par focus karenge:
#
# ---
#
# ### 1. <span style="color: #d69e2e;">***Min-Max Scaling***</span> (Most Popular)
# * Feature Scaling me casually log **Min-Max Scaling ko hi Normalization** bol dete hain kyunki ye sabse widely used method hai.
# * **Industry Reality:** Real-world projects me jab bhi aap Normalization lagayenge, lagbhag **$90\%$ times aap Min-Max Scaling ka hi use kar rahe honge**.
#
# ### 2. <span style="color: #319795;">***Mean Normalization***</span>
# * Isme data ko scale karne ke liye **Mean ($\mu$)** ka use karke center kiya jata hai, jisse values $[-1, 1]$ ya $[-\text{range}, \text{range}]$ me transform hoti hain.
#
# ### 3. <span style="color: #805ad5;">***MaxAbs Scaling (Maximum Absolute Scaling)***</span>
# * Ye feature ke **maximum absolute value** se divide karke data ko strictly **$[-1, 1]$** ke beech scale karta hai.
# * Ye sparse data (jahan bohot saare zeros hote hain) ke liye best maana jata hai.
#
# ### 4. <span style="color: #dd6b20;">***Robust Scaling***</span>
# * Ye **Median** aur **Interquartile Range (IQR)** par based hota hai.
# * **Super Power:** Agar dataset ke andar **Outliers** maujood hain, toh Robust Scaling sabse effective kaam karta hai.
#
# ---
#
# > **Note:** Scikit-Learn me aur bhi advanced scalers hain, lekin hamara main focus in 4 techniques par rahega, jisme sabse deeply hum **Min-Max Scaling** ko samjhenge aur code ke sath implement karenge.

# %% [markdown]
# ## 1. <span style="color: #2b6cb0;">***Min-Max Scaling (Mathematical Intuition)***</span>
#
# Maan lete hain hamare dataset ke **`Weight`** column me $200$ rows hain (<span style="color: #e53e3e; font-weight: bold;">$X_{\min} = 32$</span>, <span style="color: #38a169; font-weight: bold;">$X_{\max} = 130$</span>).
#
# Hume is column par **Min-Max Scaling** apply karni hai:
#
# ---
#
# ### <span style="color: #d69e2e;">***Step-by-Step Value Transformation Table***</span>
#
# | Row Index | Original Weight ($x_i$) | Min-Max Formula Step: $\frac{x_i - X_{\min}}{X_{\max} - X_{\min}}$ | Transformed Value ($x_i'$) |
# | :--- | :--- | :--- | :--- |
# | **Row 1** | <span style="color: #38a169; font-weight: bold;">130 (Max Value)</span> | $\frac{130 - 32}{130 - 32} = \frac{98}{98}$ | <span style="color: #38a169; font-weight: bold;">1.000</span> |
# | **Row 2** | **67** | $\frac{67 - 32}{130 - 32} = \frac{35}{98}$ | <span style="color: #2b6cb0; font-weight: bold;">0.357</span> |
# | **Row 3** | **81** | $\frac{81 - 32}{130 - 32} = \frac{49}{98}$ | <span style="color: #2b6cb0; font-weight: bold;">0.500</span> |
# | **Row 4** | **61** | $\frac{61 - 32}{130 - 32} = \frac{29}{98}$ | <span style="color: #2b6cb0; font-weight: bold;">0.295</span> |
# | **Row 5** | <span style="color: #e53e3e; font-weight: bold;">32 (Min Value)</span> | $\frac{32 - 32}{130 - 32} = \frac{0}{98}$ | <span style="color: #e53e3e; font-weight: bold;">0.000</span> |
# | **Row 6** | **54** | $\frac{54 - 32}{130 - 32} = \frac{22}{98}$ | <span style="color: #2b6cb0; font-weight: bold;">0.224</span> |
# | **...** | ... (200 values) | ... | <span style="color: #805ad5; font-weight: bold;">[0.0 to 1.0]</span> |
#
# ---
#
# ### <span style="color: #c53030;">***The Mathematical Formula***</span>
#
# Har individual value $x_i$ ko scale karne ka formula:
#
# $$x_i' = \frac{x_i - X_{\min}}{X_{\max} - X_{\min}}$$
#
# * <span style="color: #805ad5; font-weight: bold;">$x_i'$</span> = Scaled value (Strictly **$0$ aur $1$** ke beech aati hai).
# * <span style="color: #2b6cb0; font-weight: bold;">$x_i$</span> = Feature ki original value.
# * <span style="color: #e53e3e; font-weight: bold;">$X_{\min}$</span> = Pure column ki minimum value ($32$).
# * <span style="color: #38a169; font-weight: bold;">$X_{\max}$</span> = Pure column ki maximum value ($130$).
# * <span style="color: #d69e2e; font-weight: bold;">$X_{\max} - X_{\min}$</span> = Feature ka total range ($130 - 32 = 98$).

# %% [markdown]
# ## 2. <span style="color: #2b6cb0;">***Geometric Intuition of Min-Max Scaling***</span>
#
# Jab hum 2D dataset (jaise **Age** aur **Weight**) par **Min-Max Scaling** apply karte hain, toh geometrically pura data points ka distribution ek **unit box / unit square ($[0, 1] \times [0, 1]$)** ke andar squash (compress) ho jata hai.
#
# ---
#
# ### <span style="color: #d69e2e;">Visual Representation (2D Plane Transformation)</span>
#
# ```text
#          BEFORE MIN-MAX SCALING                          AFTER MIN-MAX SCALING
#    (Arbitrary Scales & Dimensions)                  (Bounded in [0, 1] Unit Square)
#
#  Weight (kg)                                     Weight'
#    ^                                                ^
# 130|            . - - .                          1.0|   +---------+  <-- (Unit Box)
#    |          /  x x x  \                           || x x x x |
#    |         | x x x x x |                          || x x x x |
#    |          \  x x x  /                           || x x x x |
#  32|            ' - - '                          0.0++---------+-------> Age'
#    +------------|-------|---------> Age (yrs)       0.0       1.0
#    0           18       65

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. <span style="color: #2b6cb0;">***Mean Normalization***</span>
#
# Mean Normalization me hum data ko center karne ke liye **Mean ($\bar{x}$)** ka use karte hain. Iska formula Min-Max Scaling se kaafi milta-julta hai, bas numerator me $X_{\min}$ ki jagah **$\bar{x}$ (Mean)** subtract hota hai.
#
# ---
#
# ### <span style="color: #c53030;">***Mathematical Formula***</span>
#
# Har individual data point $x_i$ ko transform karne ke liye ye formula lagta hai:
#
# $$x_i' = \frac{x_i - \bar{x}}{X_{\max} - X_{\min}}$$
#
# Yahan:
# * <span style="color: #805ad5; font-weight: bold;">$x_i'$</span> = Transformed / Scaled value
# * <span style="color: #2b6cb0; font-weight: bold;">$x_i$</span> = Original feature value
# * <span style="color: #e53e3e; font-weight: bold;">$\bar{x}$ ($\mu$)</span> = Column ka **Mean (Average)**
# * <span style="color: #38a169; font-weight: bold;">$X_{\max} - X_{\min}$</span> = Feature ka **Range** (Maximum value $-$ Minimum value)
#
# ---
#
# ### <span style="color: #d69e2e;">***Key Properties & Output Range***</span>
#
# * **Transformed Range:** Mean Normalization ke baad data values strictly **$[-1, 1]$** (ya symmetric range around 0) ke beech scale ho jati hain.
# * **Mean Centered:** Transformed data ka naya **Mean = $0$** ho jata hai.
# * **Formula Difference:**
#   * **Min-Max Scaling:** $\frac{x_i - X_{\min}}{X_{\max} - X_{\min}} \longrightarrow \text{Range: } [0, 1]$
#   * **Mean Normalization:** $\frac{x_i - \bar{x}}{X_{\max} - X_{\min}} \longrightarrow \text{Range: } [-1, 1] \text{ with Mean } 0$
#
# ---
#
# ### <span style="color: #319795;">***Kahan Use Hota Hai?***</span>
# * Jab aapko data ko **$0$ par center** bhi karna ho aur bounds ko fixed range ($[-1, 1]$) me squash bhi karna ho.
# * Scikit-Learn me iska koi direct built-in class (`MeanNormalizer`) nahi hota, log custom lambda function ya formula se calculate karte hain.

# %% [markdown]
# > **Important Note:** Mean Normalization real-world projects me **bahut rarely use hota hai**. Iski kam popularity ki wajah se **Scikit-Learn (`sklearn`) me iske liye koi dedicated class nahi banayi gayi hai** (jaise `MinMaxScaler` ya `StandardScaler` ki class hoti hai). Agar kabhi iski zaroorat padti hai, toh log Pandas/Numpy ke sath formula manually apply karte hain:
# >
# > ```python
# > # Custom Mean Normalization in Pandas
# > df_scaled = (df - df.mean()) / (df.max() - df.min())
# > ```

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. <span style="color: #2b6cb0;">***MaxAbs Scaling (Maximum Absolute Scaling)***</span>
#
# MaxAbs Scaling ek kaafi interesting technique hai. Isme hum feature ki original value ko us pure column ki **Maximum Absolute Value ($\vert{}x_i\vert{}$)** se divide karte hain.
#
# ---
#
# ### <span style="color: #c53030;">**Mathematical Formula**</span>
#
# Har individual data point $x_i$ ko transform karne ka formula:
#
# $$x_i' = \frac{x_i}{\vert{}X_{\max}\vert{}}$$
#
# Ya detailed form me:
#
# $$x_i' = \frac{x_i}{\max(\vert{}x\vert{})}$$
#
# Yahan:
# * <span style="color: #805ad5; font-weight: bold;">$x_i'$</span> = Transformed value (Z-Score jaisa bounded output).
# * <span style="color: #2b6cb0; font-weight: bold;">$x_i$</span> = Original feature value.
# * <span style="color: #e53e3e; font-weight: bold;">$\vert{}X_{\max}\vert{}$ ya $\max(\vert{}x\vert{})$</span> = Us pure column me present values ka **maximum absolute value** (chahe wo positive ho ya negative).
#
# ---
#
# ### <span style="color: #d69e2e;">**Output Range & Properties**</span>
# * Transformed values strictly **$[-1, 1]$** ke range me aati hain.
# * Ye data ko **center nahi karta** (Mean ko 0 par nahi lata), isliye existing zero values intact rehti hain ($0$ remains $0$).
#
# ---
#
# ### <span style="color: #38a169;">***Scikit-Learn Implementation***</span>
#
# Scikit-Learn me iske liye dedicated built-in class maujood hai: `MaxAbsScaler`.
#
# ```python
# from sklearn.preprocessing import MaxAbsScaler
#
# # MaxAbsScaler initialize karna
# scaler = MaxAbsScaler()
# scaled_data = scaler.fit_transform(df[['Weight']])
