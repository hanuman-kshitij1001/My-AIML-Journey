# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## What is EDA?
#
# **EDA (Exploratory Data Analysis)** is the process of **understanding and analyzing data** before applying Machine Learning or statistical models.
#
# EDA helps us find:
#
# * Missing values
# * Outliers
# * Data distribution
# * Relationships between variables
# * Important patterns in data
#
# ### Main Purpose
#
# > **First understand the data, then build the model.**
#
# ---
#
# ## Types of EDA
#
# ### 1. Univariate Analysis
#
# Analysis of **one variable** at a time.
#
# Example: Analyzing only the `Age` column.
#
# ### 2. Bivariate Analysis
#
# Analysis of **two variables** together.
#
# Example: `Age` vs `Salary`.
#
# ### 3. Multivariate Analysis
#
# Analysis of **more than two variables** together.
#
# Example: `Age`, `Experience`, `Education` and `Salary`.
#
# ---
#
# ## Next Topic
#
# We will start with **Univariate Analysis**, where we analyze **one variable at a time**.

# %% [markdown]
# # Univariate Analysis
#
# **Univariate = Single Variable**
#
# Jab hum **sirf ek variable (single column)** par EDA ya Data Analysis perform karte hain, toh usse **Univariate Analysis** kehte hain.
#
# ### Example
#
# Agar dataset mein bahut saare columns hain aur hum sirf ek column, jaise `Age`, ko analyze karte hain:
#
# ```python
# df["Age"]
# ```
#
# Toh ye **Univariate Analysis** hai.
#
# > **Single Variable / Single Column → Univariate Analysis**

# %% [markdown]
# # Types of Data
#
# Data ko mainly **2 types** mein divide kiya jata hai:
#
# ## 1. Numerical Data
#
# Numerical data woh data hota hai jo **numbers** mein hota hai aur jiske saath mathematical operations perform kar sakte hain.
#
# **Examples:**
#
# * Age
# * Salary
# * Height
# * Marks
#
# ## 2. Categorical Data
#
# Categorical data woh data hota hai jo **categories or labels** represent karta hai.
#
# **Examples:**
#
# * Gender → Male, Female
# * City → Delhi, Mumbai, Vadodara
# * Department → CSE, IT, AI/ML
#
# ### In Short
#
# **Data**
#
# * Numerical
# * Categorical

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("All_dataSet/20_Titanic-Dataset.csv")
df.head(5)
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 652          653         0       3     Kalvik, Mr. Johannes Halvorsen    male
# 657          658         0       3      Bourke, Mrs. John (Catherine)  female
# 331          332         0       1                Partner, Mr. Austen    male
# 373          374         0       1                Ringhini, Mr. Sante    male
# 393          394         1       1             Newell, Miss. Marjorie  female
# 213          214         0       2        Givard, Mr. Hans Kristensen    male
# 831          832         1       2    Richards, Master. George Sibley    male
# 688          689         0       3    Fischer, Mr. Eberhard Thelander    male
# 404          405         0       3            Oreskovic, Miss. Marija  female
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt    male
#
#        Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# 1- Categorical data ➡️

# %% [markdown]
# A- Countplot

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar', title='Survived Count', xlabel='Survived', ylabel='Count' )
# Out:
# <Axes: title={'center': 'Survived Count'}, xlabel='Survived', ylabel='Count'>

# %%
df['Pclass'].value_counts()
#sns.countplot(x='Pclass', data=df)
sns.countplot(x='Pclass', data=df, hue='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex', data=df, hue='Sex', palette='Blues')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# #### ⬆️ Sbse Jada Log jo log jo the wo male the

# %%
sns.countplot(x='Embarked', data=df, hue='Embarked',palette='mako')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ##### ⬆️ Sbse Jada Log jo Chhade the Wo S yani south....en area se chhade the

# %% [markdown]
# ⬇️ ***Agr Ab Ye Same information Percentage ke term me chhaiye Toh Tum pia chart ka use kar sakte ho***

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=["#ec2424", "#30fe02"],explode=(0.05, 0),shadow=True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### 2- Numerical Data

# %% [markdown]
# #### A- Histogram

# %%
import matplotlib.pyplot as plt
# plt.hist(df["Age"], bins=20)
plt.hist(df['Age'], bins=15, color='#66b3ff', edgecolor='black', alpha=0.9)
# Out:
# (array([ 44.,  24.,  32., 104., 115., 127.,  80.,  59.,  49.,  30.,  22.,
#          17.,   4.,   6.,   1.]),
#  array([ 0.42      ,  5.72533333, 11.03066667, 16.336     , 21.64133333,
#         26.94666667, 32.252     , 37.55733333, 42.86266667, 48.168     ,
#         53.47333333, 58.77866667, 64.084     , 69.38933333, 74.69466667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# #### B- Displot

# %%
sns.displot(df["Age"],kde=True)

# %% [markdown]
# #### C- Box-Plot-  Ye 5 number summary deta hai

# %%
sns.boxplot(df['Fare'],color='#66b3ff',width=0.5)
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)
