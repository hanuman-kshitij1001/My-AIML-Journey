# %% [markdown]
# # Day 19 — Understanding Your Data
#
# Before modeling, understand the dataset.
#
# Important questions:
#
# - How many rows?
# - How many columns?
# - What are the data types?
# - Are there missing values?
# - Are there duplicates?
# - What is the target?
# - Are there outliers?

# %%
import pandas as pd
import numpy as np

# df = pd.read_csv("data.csv")

# Basic inspection
# print(df.head())
# print(df.tail())
# print(df.shape)
# print(df.columns)
# print(df.info())
# print(df.describe())

# %% [markdown]
# ## Missing Values

# %%
# df.isnull().sum()

# Missing percentage
# missing_percentage = df.isnull().mean() * 100
# print(missing_percentage)

# %% [markdown]
# ## Duplicate Rows

# %%
# print(df.duplicated().sum())

# Remove duplicates
# df = df.drop_duplicates()

# %% [markdown]
# ## Data Types
#
# Common types:
#
# int
# float
# object/string
# bool
# datetime
#
# Categorical columns usually need encoding before many ML algorithms.
