# %% [markdown]
# # Day 16 — Working with JSON and SQL
#
# Machine Learning data does not always come as CSV.
#
# Two important formats/sources:
#
# - JSON
# - SQL databases

# %% [markdown]
# ## JSON
#
# JSON stands for JavaScript Object Notation.
#
# It is commonly used by APIs.
#
# Example:
#
# {
#     "name": "Kshitij",
#     "age": 22,
#     "skills": ["Python", "ML"]
# }

# %%
import pandas as pd
import json

# JSON file
# df = pd.read_json("data.json")

# JSON string
data = '''
[
    {"name": "A", "age": 20},
    {"name": "B", "age": 22}
]
'''

df = pd.read_json(data)

print(df)

# %% [markdown]
# ## SQL
#
# SQL databases store structured data in tables.
#
# Important SQL operations:
#
# SELECT
# WHERE
# GROUP BY
# ORDER BY
# JOIN

# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect("example.db")

query = "SELECT * FROM users"

# df = pd.read_sql(query, connection)

connection.close()
