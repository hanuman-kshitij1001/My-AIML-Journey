# %%
# Data Analysis Process
# In this step, the data is to be understood more deeply. Before implementing methods to clean it, you will definitely need to have a better idea about what the data is about.

# %%
import pandas as pd

adverse_reactions = pd.read_csv("../Data_set/01_adverse_reactions.csv")
patients = pd.read_csv("../Data_set/02_patients.csv")
treatments = pd.read_csv("../Data_set/03_treatments.csv")
treatments_cut = pd.read_csv("../Data_set/04_treatments_cut.csv")

# %%
adverse_reactions

# %%
patients

# %%
treatments

# %%
treatments_cut

# %%
import pandas as pd
import numpy as np

# Ess Data set pee Haam Karne wale hai Theek 
patients = pd.read_csv("../Data_set/02_patients.csv")

df = patients.head()
print(df)

# %%
tr = treatments.head()
print(tr)

# %%
shape = treatments.shape
print(shape)
