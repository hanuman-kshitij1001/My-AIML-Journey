# %%
import json
import pandas as pd
with open("trains.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
features = data["features"]

# %%
df = pd.json_normalize(features)

# %%
df.columns

# %%
df.columns = df.columns.str.replace("properties.", "", regex=False)
df.columns = df.columns.str.replace("geometry.", "", regex=False)

# %%
df

# %%
df.columns

# %%
df = df.rename(columns={
    "geometry.type": "geometry_type",
    "geometry.coordinates": "coordinates",
    "type": "Type"
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = df.rename(columns={
#       2     "geometry.type": "geometry_type",
#       3     "geometry.coordinates": "coordinates",
#       4     "type": "Type"
#
# NameError: name 'df' is not defined

# %%
df

# %%
import pandas as pd 
df = pd.read_csv("FastagFraudDetection.csv")
df
# Out:
#       Transaction_ID        Timestamp Vehicle_Type         FastagID  \
# 0                  1   1/6/2023 11:20         Bus   FTG-001-ABC-121
# 1                  2   1/7/2023 14:55          Car  FTG-002-XYZ-451
# 2                  3   1/8/2023 18:25   Motorcycle              NaN
# 3                  4    1/9/2023 2:05        Truck  FTG-044-LMN-322
# 4                  5   1/10/2023 6:35          Van  FTG-505-DEF-652
# ...              ...              ...          ...              ...
# 4995            4996   1/1/2023 22:18        Truck  FTG-445-EDC-765
# 4996            4997  1/17/2023 13:43          Van  FTG-446-LMK-432
# 4997            4998    2/5/2023 5:08        Sedan  FTG-447-PLN-109
# 4998            4999  2/20/2023 20:34          SUV  FTG-458-VFR-876
# 4999            5000   3/10/2023 0:59         Bus   FTG-459-WSX-543
#
#      TollBoothID Lane_Type Vehicle_Dimensions  Transaction_Amount  \
# 0          A-101   Express              Large                 350
# ...

# %%
df.shape

# %%
df.dtypes

# %%
df.index

# %%
df.columns

# %%
df.values

# %%
df.head()

# %%
df.tail()

# %%
df.sample()

# %%
df.info

# %%
df.describe

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.duplicated()

# %%
data_set = pd.read_csv("Titanic-Dataset.csv")
data_set

# %%
duplicate = data_set["PassengerId"].duplicated().value_counts()
duplicate

# %%
df = data_set[data_set.duplicated()]
df

# %%
data_set["Name"].duplicated()

# %%
data_set[data_set.duplicated()]

# %%
data_set

# %%
data_set.info()

# %%
data_set.describe()

# %%
# Maths Method

# %%
# Now move to the  ppata nahi kaha par ja raha hun 
data = df["Timestamp"]
data
# Out:
# 0        1/6/2023 11:20
# 1        1/7/2023 14:55
# 2        1/8/2023 18:25
# 3         1/9/2023 2:05
# 4        1/10/2023 6:35
#              ...
# 4995     1/1/2023 22:18
# 4996    1/17/2023 13:43
# 4997      2/5/2023 5:08
# 4998    2/20/2023 20:34
# 4999     3/10/2023 0:59
# Name: Timestamp, Length: 5000, dtype: object
